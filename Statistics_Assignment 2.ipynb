# %% [markdown]
# # What is covariance matrix ?

# %% [markdown]
# ### a type of matrix that is used to represent the covariance values between pairs of elements given in a random vector

# %% [markdown]
# ![image-%282%29.png](attachment:image-%282%29.png)

# %% [markdown]
# ## Covariance Matrix Equation:

# %% [markdown]
# ![images.png](attachment:images.png)

# %% [markdown]
# # What are Eigen Vectors and Eigen values ?

# %% [markdown]
# ### An eigenvector corresponds to the real non zero eigenvalues which point in the direction stretched by the transformation

# %% [markdown]
# ![maxresdefault.jpg](attachment:maxresdefault.jpg)

# %% [markdown]
# # A Python code that calculates the covariance matrix and finds the eigenvalues and eigenvectors of a matrix.

# %% [markdown]
# ## Importing numpy:

# %%
import numpy as np

# %% [markdown]
# ## Sample data:

# %%
data = np.array([
    [2.5, 2.4],
    [0.5, 0.7],
    [2.2, 2.9],
    [1.9, 2.2],
    [3.1, 3.0],
    [2.3, 2.7],
    [2, 1.6],
    [1, 1.1],
    [1.5, 1.6],
    [1.1, 0.9]
])

# %% [markdown]
# ## Compute the mean:

# %%
mean = np.mean(data, axis=0)

# %% [markdown]
# ## Center the data:

# %%
centered_data = data - mean

# %% [markdown]
# ## Compute the covariance matrix:

# %%
cov_matrix = np.cov(centered_data, rowvar=False)

# %% [markdown]
# ## Compute eigenvalues and eigenvectors:

# %%
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

# %%
print("Covariance Matrix:\n", cov_matrix)
print("\nEigenvalues:\n", eigenvalues)
print("\nEigenvectors:\n", eigenvectors)
# Out:
# Covariance Matrix:
#  [[0.61655556 0.61544444]
#  [0.61544444 0.71655556]]
#
# Eigenvalues:
#  [0.0490834  1.28402771]
#
# Eigenvectors:
#  [[-0.73517866 -0.6778734 ]
#  [ 0.6778734  -0.73517866]]
